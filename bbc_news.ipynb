# %% [markdown]
# <a href="https://colab.research.google.com/github/abdallahsidibe/Data_Projet/blob/master/bbc_news.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install beautifulsoup4

# %%
# pip install requests

# %%
# importer les packages
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# saisir l'URL
url = "http://feeds.bbci.co.uk/news/rss.xml"

# %%
# importer le code de la page
reponse =  requests.get(url)
soup = BeautifulSoup(reponse.text, "html.parser")
soup
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
# <rss version="2.0" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:media="http://search.yahoo.com/mrss/">
# <channel>
# <title><![CDATA[BBC News - Home]]></title>
# <description><![CDATA[BBC News - Home]]></description>
# ...

# %%
items = soup.findAll('item')

# %%
item = items[0]

# %%
item.title.text
item.description.text
# Out:
# 'The bodies of Hugo Morris, Harvey Owen, Wilf Fitchett and Jevon Hirst were found in a crashed car.'

# %%
news_items = []

# %%
for i in items:
  news_i = {}
  news_i['title'] = i.title.text
  news_i['description'] = i.description.text
  news_i['pubdate'] = i.pubdate.text
  news_items.append(news_i)

# %%
news_items
# Out:
# [{'title': 'North Wales: Four missing teens drowned after crash, inquest hears',
#   'description': 'The bodies of Hugo Morris, Harvey Owen, Wilf Fitchett and Jevon Hirst were found in a crashed car.',
#   'pubdate': 'Wed, 29 Nov 2023 11:53:01 GMT'},
#  {'title': 'Shoppers hit by escalating prices of branded goods',
#   'description': 'Baby formula is one of the areas in which prices have risen by more than costs, a watchdog says.',
#   'pubdate': 'Wed, 29 Nov 2023 12:55:54 GMT'},
#  {'title': 'Boy, 13, killed foster mother Marcia Grant with her own car',
#   'description': "The boy, who cannot be named for legal reasons, is detained for two years over Marcia Grant's death.",
#   'pubdate': 'Wed, 29 Nov 2023 14:05:03 GMT'},
#  {'title': "Beyoncé's mum hits out at 'racist' skin lightening comments",
#   'description': 'The singer had platinum blonde hair at the red carpet event for her Renaissance film premiere.',
#   'pubdate': 'Wed, 29 Nov 2023 11:02:43 GMT'},
# ...

# %%
# convertir la liste de dictionnaire en DB
df = pd.DataFrame(news_items, columns=['title', 'description', 'pubdate'])

# %%
df.head()
# Out:
#                                                title  \
# 0  North Wales: Four missing teens drowned after ...
# 1  Shoppers hit by escalating prices of branded g...
# 2  Boy, 13, killed foster mother Marcia Grant wit...
# 3  Beyoncé's mum hits out at 'racist' skin lighte...
# 4  Paramedic pushed out of London ambulance by pa...
#
#                                          description  \
# 0  The bodies of Hugo Morris, Harvey Owen, Wilf F...
# 1  Baby formula is one of the areas in which pric...
# 2  The boy, who cannot be named for legal reasons...
# 3  The singer had platinum blonde hair at the red...
# 4  The paramedic can be seen crashing to the grou...
#
#                          pubdate
# 0  Wed, 29 Nov 2023 11:53:01 GMT
# 1  Wed, 29 Nov 2023 12:55:54 GMT
# 2  Wed, 29 Nov 2023 14:05:03 GMT
# 3  Wed, 29 Nov 2023 11:02:43 GMT
# 4  Wed, 29 Nov 2023 13:23:06 GMT

# %%
df.to_csv('bbc_news.csv', index=False, encoding='utf-8')
